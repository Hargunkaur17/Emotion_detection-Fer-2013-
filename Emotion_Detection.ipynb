# %% [markdown]
# **Emotion Detection**

# %% [markdown]
# **Importing Libraries**

# %%
import matplotlib.pyplot as plt
from glob import glob
import cv2
import random
import os
# %matplotlib inline

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Dense, Input, Dropout, Flatten, Conv2D
from tensorflow.keras.layers import BatchNormalization, Activation, MaxPooling2D
from tensorflow.keras.models import Model,Sequential
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras.utils import plot_model

from IPython.display import SVG, Image
import tensorflow as tf
print("Tensorflow version",tf.__version__)
# Out:
# Tensorflow version 2.13.0

# %% [markdown]
# Exploring Dataset

# %%
images=glob("train/**/**")
for i in range(9):
    image=random.choice(images)
    plt.figure(figsize=(12,12))
    plt.subplot(331+i)
    plt.imshow(cv2.imread(image));plt.axis('off')

# %% [markdown]
# **Preparing data for training**

# %%
img_size=48
batch_size=64
datagen_train= ImageDataGenerator()
train_generator=datagen_train.flow_from_directory("train/",
                                                  target_size=(img_size,img_size),
                                                  color_mode="grayscale",
                                                  batch_size=batch_size,
                                                  class_mode="categorical",
                                                  shuffle=True)
datagen_validation=ImageDataGenerator()
validation_generator=datagen_train.flow_from_directory("test/",
                                                   target_size=(img_size,img_size),
                                                  color_mode="grayscale",
                                                  batch_size=batch_size,
                                                  class_mode="categorical",
                                                  shuffle=True)
# Out:
# Found 28709 images belonging to 7 classes.
# Found 7178 images belonging to 7 classes.

# %% [markdown]
# **Defining Model**

# %%
def Convolution(input_tensor,filters,kernel_size):
    x=Conv2D(filters,kernel_size=kernel_size, padding="same")(input_tensor)
    x=BatchNormalization()(x)
    x=Activation("relu")(x)
    x=MaxPooling2D(pool_size=(2,2))(x)
    x=Dropout(0.25)(x)

    return x

# %%
def model_fer(input_shape):
    inputs=Input(input_shape)
    conv_1=Convolution(inputs,32,(3,3))
    conv_2=Convolution(inputs,64,(5,5))
    conv_3=Convolution(inputs,128,(3,3))
    flatten=Flatten()(conv_3)
    dense_1=Dense(256)(flatten)
    output=Dense(7,activation="softmax")(dense_1)
    model=Model(inputs=inputs, outputs=output)
    model.compile(loss="categorical_crossentropy", optimizer="adam", metrics=["accuracy"])
    return model

# %%
model=model_fer((48,48,1))
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 48, 48, 1)]       0
#
#  conv2d_2 (Conv2D)           (None, 48, 48, 128)       1280
#
#  batch_normalization_2 (Bat  (None, 48, 48, 128)       512
#  chNormalization)
#
#  activation_2 (Activation)   (None, 48, 48, 128)       0
#
#  max_pooling2d_2 (MaxPoolin  (None, 24, 24, 128)       0
#  g2D)
#
#  dropout_2 (Dropout)         (None, 24, 24, 128)       0
#
#  flatten (Flatten)           (None, 73728)             0
#
#  dense (Dense)               (None, 256)               18874624
#
#  dense_1 (Dense)             (None, 7)                 1799
#
# =================================================================
# Total params: 18878215 (72.01 MB)
# Trainable params: 18877959 (72.01 MB)
# Non-trainable params: 256 (1.00 KB)
# _________________________________________________________________

# %% [markdown]
# **Initializing the model**

# %%
epochs=15
steps_per_epoch=train_generator.n//train_generator.batch_size
validation_steps=validation_generator.n//validation_generator.batch_size
checkpoint=ModelCheckpoint("model_weights.h5",monitor="val_accuracy",save_weights_only=True,mode="max",verbose=1)
callbacks=[checkpoint]

# %% [markdown]
# **Training the Model**

# %%
history=model.fit(
x=train_generator,
steps_per_epoch=steps_per_epoch,
epochs=epochs,
validation_data=validation_generator,
validation_steps=validation_steps,
callbacks=callbacks)
# Out:
# Epoch 1/15
# 448/448 [==============================] - ETA: 0s - loss: 29.5046 - accuracy: 0.2980
# Epoch 1: saving model to model_weights.h5
# 448/448 [==============================] - 261s 579ms/step - loss: 29.5046 - accuracy: 0.2980 - val_loss: 8.5275 - val_accuracy: 0.3340
# Epoch 2/15
# 448/448 [==============================] - ETA: 0s - loss: 4.1159 - accuracy: 0.3904
# Epoch 2: saving model to model_weights.h5
# 448/448 [==============================] - 246s 549ms/step - loss: 4.1159 - accuracy: 0.3904 - val_loss: 1.9774 - val_accuracy: 0.3937
# Epoch 3/15
# 448/448 [==============================] - ETA: 0s - loss: 1.6912 - accuracy: 0.4456
# Epoch 3: saving model to model_weights.h5
# 448/448 [==============================] - 249s 556ms/step - loss: 1.6912 - accuracy: 0.4456 - val_loss: 1.5305 - val_accuracy: 0.4471
# Epoch 4/15
# 448/448 [==============================] - ETA: 0s - loss: 1.3682 - accuracy: 0.4922
# Epoch 4: saving model to model_weights.h5
# 448/448 [==============================] - 241s 539ms/step - loss: 1.3682 - accuracy: 0.4922 - val_loss: 1.4994 - val_accuracy: 0.4438
# Epoch 5/15
# 448/448 [==============================] - ETA: 0s - loss: 1.3293 - accuracy: 0.5014
# Epoch 5: saving model to model_weights.h5
# 448/448 [==============================] - 245s 546ms/step - loss: 1.3293 - accuracy: 0.5014 - val_loss: 1.4524 - val_accuracy: 0.4537
# Epoch 6/15
# 448/448 [==============================] - ETA: 0s - loss: 1.3064 - accuracy: 0.5091
# Epoch 6: saving model to model_weights.h5
# 448/448 [==============================] - 239s 534ms/step - loss: 1.3064 - accuracy: 0.5091 - val_loss: 1.5160 - val_accuracy: 0.4350
# Epoch 7/15
# 448/448 [==============================] - ETA: 0s - loss: 1.3014 - accuracy: 0.5070
# Epoch 7: saving model to model_weights.h5
# 448/448 [==============================] - 254s 568ms/step - loss: 1.3014 - accuracy: 0.5070 - val_loss: 1.4913 - val_accuracy: 0.4308
# Epoch 8/15
# 448/448 [==============================] - ETA: 0s - loss: 1.2924 - accuracy: 0.5163
# Epoch 8: saving model to model_weights.h5
# 448/448 [==============================] - 250s 557ms/step - loss: 1.2924 - accuracy: 0.5163 - val_loss: 1.4619 - val_accuracy: 0.4517
# Epoch 9/15
# 448/448 [==============================] - ETA: 0s - loss: 1.2949 - accuracy: 0.5132
# Epoch 9: saving model to model_weights.h5
# 448/448 [==============================] - 240s 535ms/step - loss: 1.2949 - accuracy: 0.5132 - val_loss: 1.6323 - val_accuracy: 0.4128
# Epoch 10/15
# 448/448 [==============================] - ETA: 0s - loss: 1.2967 - accuracy: 0.5131
# Epoch 10: saving model to model_weights.h5
# 448/448 [==============================] - 234s 522ms/step - loss: 1.2967 - accuracy: 0.5131 - val_loss: 1.5703 - val_accuracy: 0.4206
# Epoch 11/15
# 448/448 [==============================] - ETA: 0s - loss: 1.2898 - accuracy: 0.5204
# Epoch 11: saving model to model_weights.h5
# 448/448 [==============================] - 228s 509ms/step - loss: 1.2898 - accuracy: 0.5204 - val_loss: 1.5614 - val_accuracy: 0.4270
# Epoch 12/15
# 448/448 [==============================] - ETA: 0s - loss: 1.2767 - accuracy: 0.5233
# Epoch 12: saving model to model_weights.h5
# 448/448 [==============================] - 252s 562ms/step - loss: 1.2767 - accuracy: 0.5233 - val_loss: 1.4464 - val_accuracy: 0.4574
# Epoch 13/15
# 448/448 [==============================] - ETA: 0s - loss: 1.2505 - accuracy: 0.5354
# Epoch 13: saving model to model_weights.h5
# 448/448 [==============================] - 245s 546ms/step - loss: 1.2505 - accuracy: 0.5354 - val_loss: 1.5785 - val_accuracy: 0.4297
# Epoch 14/15
# 448/448 [==============================] - ETA: 0s - loss: 1.2484 - accuracy: 0.5375
# Epoch 14: saving model to model_weights.h5
# 448/448 [==============================] - 302s 673ms/step - loss: 1.2484 - accuracy: 0.5375 - val_loss: 1.5636 - val_accuracy: 0.4506
# Epoch 15/15
# 448/448 [==============================] - ETA: 0s - loss: 1.1980 - accuracy: 0.5581
# Epoch 15: saving model to model_weights.h5
# 448/448 [==============================] - 295s 657ms/step - loss: 1.1980 - accuracy: 0.5581 - val_loss: 1.7618 - val_accuracy: 0.4210

# %% [markdown]
# **Evaluate the model**

# %%
model.evaluate(validation_generator)
# Out:
# 113/113 [==============================] - 9s 77ms/step - loss: 1.7621 - accuracy: 0.4207
# [1.762137532234192, 0.42072999477386475]

# %% [markdown]
# **Plotting Loss**

# %%
plt.plot(history.history["loss"])
plt.plot(history.history["val_loss"])
plt.title("Model Loss")
plt.legend(["Train,Validation"],loc="upper left")
plt.subplots_adjust(top=1.0,bottom=0.0,right=0.95,left=0.0,hspace=0.25,wspace=0.35)

# %% [markdown]
# **Plot Accuracy**

# %%
plt.plot(history.history["accuracy"])
plt.plot(history.history["val_accuracy"])
plt.title("Model Accuracy")
plt.legend(["Train,Validation"],loc="upper left")
plt.subplots_adjust(top=1.0,bottom=0.0,right=0.95,left=0.0,hspace=0.25,wspace=0.35)

# %% [markdown]
# **Saving Model**

# %%
model_json=model.to_json()
with open("model_a.json","w") as json_file:
    json_file.write(model_json)
